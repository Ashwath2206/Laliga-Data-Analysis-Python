# %% [markdown]
# # LALIGA SCORES BUSINESS REPORT
# ### ASHWATH J

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\Intel\\Downloads\\Laliga_scores.csv',header=1)
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
df=pd.read_csv('C:\\Users\\Intel\\Downloads\\Laliga_scores.csv',header=1)
df=df.replace(to_replace='-',
    value=0)

# %%
df.describe()
# Out:
#              Pos    Seasons       Points  GamesPlayed     GamesWon  \
# count  61.000000  61.000000    61.000000    61.000000    61.000000
# mean   31.000000  24.000000   901.426230   796.819672   303.967213
# std    17.752934  26.827225  1134.899121   876.282765   406.991030
# min     1.000000   1.000000     0.000000     0.000000     0.000000
# 25%    16.000000   4.000000    96.000000   114.000000    34.000000
# 50%    31.000000  12.000000   375.000000   423.000000   123.000000
# 75%    46.000000  38.000000  1351.000000  1318.000000   426.000000
# max    61.000000  86.000000  4385.000000  2762.000000  1647.000000
#
#           GoalsFor  GoalsAgainst        Debut  BestPosition  Goal_diff_count  \
# count    61.000000     61.000000    61.000000     61.000000        61.000000
# mean   1140.344262   1140.229508  1958.918033      7.081967         0.114754
# std    1506.740211   1163.710766    27.484114      5.276663       598.095814
# ...

# %%
df.dtypes
# Out:
# Pos              int64
# Team            object
# Seasons          int64
# Points          object
# GamesPlayed     object
# GamesWon        object
# GamesDrawn      object
# GamesLost       object
# GoalsFor        object
# GoalsAgainst    object
# Champion        object
# Runner-up       object
# Third           object
# Fourth          object
# Fifth           object
# Sixth           object
# Debut           object
# BestPosition     int64
# dtype: object

# %%
df['BestPosition']=pd.to_numeric(df['BestPosition'])
best_pos=df['BestPosition']
best_pos.describe()
# Out:
# count    61.000000
# mean      7.081967
# std       5.276663
# min       1.000000
# 25%       3.000000
# 50%       6.000000
# 75%      10.000000
# max      20.000000
# Name: BestPosition, dtype: float64

# %%
df[df['BestPosition']==1]['Team']
# Out:
# 0             Real Madrid
# 1               Barcelona
# 2         Atletico Madrid
# 3                Valencia
# 4         Athletic Bilbao
# 5                 Sevilla
# 7           Real Sociedad
# 9              Real Betis
# 10    Deportivo La Coruna
# Name: Team, dtype: object

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.distplot(best_pos,kde=False,bins=np.arange(10));
# Out:
# C:\Users\Intel\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(best_pos)
# Out:
# C:\Users\Intel\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BestPosition'>

# %% [markdown]
# Question 2

# %%
a=df['Debut']
b=[]
for i in a:
    b.append(i[0:4])
df['Debut']=b
df['Debut']=pd.to_numeric(df['Debut'])

# %%
new_df=df[(df['Debut']>=1930) & (df['Debut'] <1980)].reset_index()
new_df
# Out:
#     index  Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0       3    4             Valencia       82    3386         2664      1187
# 1       5    6              Sevilla       73    2819         2408       990
# 2       8    9             Zaragoza       58    2109         1986       698
# 3       9   10           Real Betis       51    1884         1728       606
# 4      10   11  Deportivo La Coruna       45    1814         1530       563
# 5      11   12           Celta Vigo       51    1789         1698       586
# 6      12   13           Valladolid       42    1471         1466       463
# 7      14   15       Sporting Gijon       43    1389         1458       471
# 8      15   16              Osasuna       37    1351         1318       426
# 9      16   17               Malaga       36    1314         1255       390
# 10     17   18               Oviedo       38    1174         1192       408
# ...

# %%
new_df['Team'].nunique()
# Out:
# 37

# %% [markdown]
# Question 3

# %%
df['Points']=pd.to_numeric(df['Points'])
dfq3=df.sort_values(by='Points',ascending=False).head(5)
dfq3
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385        2762     1647        552
# 1    2        Barcelona       86    4262        2762     1581        573
# 2    3  Atletico Madrid       80    3442        2614     1241        598
# 3    4         Valencia       82    3386        2664     1187        616
# 4    5  Athletic Bilbao       86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#    Debut  BestPosition
# 0   1929             1
# ...

# %%
dfq3[['Team','Points']]
# Out:
#               Team  Points
# 0      Real Madrid    4385
# 1        Barcelona    4262
# 2  Atletico Madrid    3442
# 3         Valencia    3386
# 4  Athletic Bilbao    3368

# %% [markdown]
# QUESTION 4

# %%
df['GoalsFor']=pd.to_numeric(df['GoalsFor'])
df['GoalsAgainst']=pd.to_numeric(df['GoalsAgainst'])

def Goal_diff_count(a,b):
    return a-b
df['Goal_diff_count'] = df.apply(lambda x: Goal_diff_count(x['GoalsFor'], x['GoalsAgainst']), axis=1)
df
# Out:
#     Pos              Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86    4385        2762     1647        552
# 1     2         Barcelona       86    4262        2762     1581        573
# 2     3   Atletico Madrid       80    3442        2614     1241        598
# 3     4          Valencia       82    3386        2664     1187        616
# 4     5   Athletic Bilbao       86    3368        2762     1209        633
# ..  ...               ...      ...     ...         ...      ...        ...
# 56   57             Xerez        1      34          38        8         10
# 57   58            Condal        1      22          30        7          8
# 58   59   Atletico Tetuan        1      19          30        7          5
# 59   60  Cultural Leonesa        1      14          30        5          4
# 60   61            Girona        1       0           0        0          0
#
# ...

# %%
df[['Team','Goal_diff_count']]
# Out:
#                 Team  Goal_diff_count
# 0        Real Madrid             2807
# 1          Barcelona             2786
# 2    Atletico Madrid             1225
# 3           Valencia              929
# 4    Athletic Bilbao              931
# ..               ...              ...
# 56             Xerez              -28
# 57            Condal              -20
# 58   Atletico Tetuan              -34
# 59  Cultural Leonesa              -31
# 60            Girona                0
#
# [61 rows x 2 columns]

# %%
QUESTION 5

# %%
a=df['Goal_diff_count'].max()
a
# Out:
# 2807

# %%
b=df['Goal_diff_count'].min()
b
# Out:
# -525

# %%
df[df['Goal_diff_count']==a]['Team']
# Out:
# 0    Real Madrid
# Name: Team, dtype: object

# %%
df[df['Goal_diff_count']==b]['Team']
# Out:
# 13    Racing Santander
# Name: Team, dtype: object

# %% [markdown]
# Question 6

# %%
df['GamesWon']=pd.to_numeric(df['GamesWon'])
df['GamesPlayed']=pd.to_numeric(df['GamesPlayed'])
def percent_of_winning(a,b):
    if b!=0:
        return (a/b)*100
    else:
        return 0
df['Winning Percent']=df.apply(lambda x:percent_of_winning(x['GamesWon'],x['GamesPlayed']),axis=1)
df
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0     1       Real Madrid       86    4385         2762      1647        552
# 1     2         Barcelona       86    4262         2762      1581        573
# 2     3   Atletico Madrid       80    3442         2614      1241        598
# 3     4          Valencia       82    3386         2664      1187        616
# 4     5   Athletic Bilbao       86    3368         2762      1209        633
# ..  ...               ...      ...     ...          ...       ...        ...
# 56   57             Xerez        1      34           38         8         10
# 57   58            Condal        1      22           30         7          8
# 58   59   Atletico Tetuan        1      19           30         7          5
# 59   60  Cultural Leonesa        1      14           30         5          4
# 60   61            Girona        1       0            0         0          0
#
# ...

# %% [markdown]
# Question 7

# %%
dfq7=df.sort_values(by='Winning Percent',ascending=False).head(5)
dfq7
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 0       563      5947          3140       33        23     8      8     3
# 1       608      5900          3114       25        25    12     12     4
# 2       775      4534          3309       10         8    16      9     7
# 3       861      4398          3469        6         6    10     11    10
# 4       920      4631          3700        8         7    10      5     8
#
#   Sixth  Debut  BestPosition  Goal_diff_count  Winning Percent
# ...

# %%
dfq7[['Team','Winning Percent']]
# Out:
#               Team  Winning Percent
# 0      Real Madrid        59.630702
# 1        Barcelona        57.241130
# 2  Atletico Madrid        47.475134
# 3         Valencia        44.557057
# 4  Athletic Bilbao        43.772629

# %% [markdown]
# QUESTION 8

# %%
z=df.groupby('BestPosition')['Points'].sum()
dfq8=pd.DataFrame(z)
dfq8
# Out:
#               Points
# BestPosition
# 1              27933
# 2               6904
# 3               5221
# 4               6563
# 5               1884
# 6               2113
# 7               1186
# 8               1134
# 9                 96
# 10               450
# 11               445
# 12               511
# 14                71
# 15                14
# 16                81
# 17               266
# 19                81
# 20                34
